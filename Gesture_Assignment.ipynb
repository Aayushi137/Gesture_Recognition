# %% [markdown]
# Problem Statement:
# ==================
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# Gesture	Corresponding Action:
# ==============================
# -Thumbs Up	Increase the volume.
# -Thumbs Down	Decrease the volume.
# -Left Swipe	'Jump' backwards 10 seconds.
# -Right Swipe	'Jump' forward 10 seconds.
# -Stop	Pause the movie.
# -Each video is a sequence of 30 frames (or images).
#
# Objectives:
# Generator:
# =========
# The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# Model:
# =====
# Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# Write up:
# =========
# This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.

# %%
# !nvidia-smi
# Out:
# Mon May 16 22:39:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 470.42.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 5000     Off  | 00000000:1C:00.0 Off |                  Off |
# | 33%   33C    P0    38W / 230W |      0MiB / 16125MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Quadro RTX 5000     Off  | 00000000:1E:00.0 Off |                  Off |
# | 33%   35C    P0    46W / 230W |      0MiB / 16125MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Quadro RTX 5000     Off  | 00000000:3D:00.0 Off |                  Off |
# | 33%   31C    P0    44W / 230W |      0MiB / 16125MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Quadro RTX 5000     Off  | 00000000:3F:00.0 Off |                  Off |
# | 32%   32C    P0    45W / 230W |      0MiB / 16125MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Quadro RTX 5000     Off  | 00000000:40:00.0 Off |                  Off |
# | 31%   33C    P0    49W / 230W |      0MiB / 16125MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  Quadro RTX 5000     Off  | 00000000:41:00.0 Off |                  Off |
# | 31%   31C    P0    49W / 230W |      0MiB / 16125MiB |      5%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#importing libraries
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os
import warnings
warnings.filterwarnings("ignore")
import abc
from sys import getsizeof
import cv2
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %%
project_folder='datasets/Project_data'
train_doc = np.random.permutation(open('datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('datasets/Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [raw]
# Generator
# =========
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with img_idx, y,z and normalization such that you get high accuracy.

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # MOST IMPORTANT PART HERE - The generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [raw]
# Model
# =====
# Here you make the model using different functionalities that Keras provides. Remember to use Conv3D and MaxPooling3D and not Conv2D and Maxpooling2D for a 3D convolution model. You would want to use TimeDistributed while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=10,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# 2022-05-17 05:31:45.156487: I tensorflow/core/platform/cpu_feature_guard.cc:152] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-17 05:31:52.738741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22116 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:88:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 160, 160, 16)  1312
#
#  activation (Activation)     (None, 30, 160, 160, 16)  0
#
#  batch_normalization (BatchN  (None, 30, 160, 160, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 80, 80, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 80, 80, 32)    4128
#
#  activation_1 (Activation)   (None, 15, 80, 80, 32)    0
#
#  batch_normalization_1 (Batc  (None, 15, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 40, 40, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 40, 40, 64)     16448
#
#  activation_2 (Activation)   (None, 7, 40, 40, 64)     0
#
#  batch_normalization_2 (Batc  (None, 7, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 20, 20, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 20, 20, 128)    65664
#
#  activation_3 (Activation)   (None, 3, 20, 20, 128)    0
#
#  batch_normalization_3 (Batc  (None, 3, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 128)               1638528
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________

# %%
from skimage.transform import resize

# %%
test_generator=ModelConv3D1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])   
plt.show()

# %% [raw]
# Checking with Image resolution, Num of frames to use and batch size

# %%
conv_3d1.train_model(conv_3d1_model)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2022-05-16 22:42:53.744644: I tensorflow/stream_executor/cuda/cuda_dnn.cc:379] Loaded cuDNN version 8303
# 67/67 [==============================] - ETA: 0s - loss: 1.5826 - categorical_accuracy: 0.3997
# Epoch 1: val_loss improved from inf to 8.25617, saving model to model_init_2022-05-1622_42_46.931117/model-00001-1.58257-0.39970-8.25617-0.16000.h5
# 67/67 [==============================] - 186s 3s/step - loss: 1.5826 - categorical_accuracy: 0.3997 - val_loss: 8.2562 - val_categorical_accuracy: 0.1600 - lr: 0.0010

# %% [raw]
# Checking how training time is affected after changing the image resolution, number of images in sequence and batch size

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=30,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 687813
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 23/23 [==============================] - ETA: 0s - loss: 1.5561 - categorical_accuracy: 0.4238
# Epoch 1: val_loss improved from inf to 2.18968, saving model to model_init_2022-05-1622_45_55.657896/model-00001-1.55606-0.42383-2.18968-0.17000.h5
# 23/23 [==============================] - 102s 5s/step - loss: 1.5561 - categorical_accuracy: 0.4238 - val_loss: 2.1897 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 2/2
# 23/23 [==============================] - ETA: 0s - loss: 1.0253 - categorical_accuracy: 0.6139
# Epoch 2: val_loss did not improve from 2.18968
# 23/23 [==============================] - 102s 5s/step - loss: 1.0253 - categorical_accuracy: 0.6139 - val_loss: 4.4812 - val_categorical_accuracy: 0.2000 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=20,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 687813
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 34/34 [==============================] - ETA: 0s - loss: 1.6742 - categorical_accuracy: 0.3846
# Epoch 1: val_loss improved from inf to 3.14109, saving model to model_init_2022-05-1622_49_23.963972/model-00001-1.67415-0.38462-3.14109-0.22000.h5
# 34/34 [==============================] - 154s 5s/step - loss: 1.6742 - categorical_accuracy: 0.3846 - val_loss: 3.1411 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/2
# 34/34 [==============================] - ETA: 0s - loss: 1.0999 - categorical_accuracy: 0.5701
# Epoch 2: val_loss did not improve from 3.14109
# 34/34 [==============================] - 150s 5s/step - loss: 1.0999 - categorical_accuracy: 0.5701 - val_loss: 6.8118 - val_categorical_accuracy: 0.2000 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=15,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 45/45 [==============================] - ETA: 0s - loss: 1.5465 - categorical_accuracy: 0.4404
# Epoch 1: val_loss improved from inf to 7.23987, saving model to model_init_2022-05-1622_54_32.828177/model-00001-1.54648-0.44042-7.23987-0.16000.h5
# 45/45 [==============================] - 174s 4s/step - loss: 1.5465 - categorical_accuracy: 0.4404 - val_loss: 7.2399 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/2
# 45/45 [==============================] - ETA: 0s - loss: 0.9967 - categorical_accuracy: 0.6229
# Epoch 2: val_loss did not improve from 7.23987
# 45/45 [==============================] - 173s 4s/step - loss: 0.9967 - categorical_accuracy: 0.6229 - val_loss: 10.9135 - val_categorical_accuracy: 0.1400 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 23/23 [==============================] - ETA: 0s - loss: 1.5231 - categorical_accuracy: 0.4118
# Epoch 1: val_loss improved from inf to 1.83475, saving model to model_init_2022-05-1623_00_24.019391/model-00001-1.52309-0.41176-1.83475-0.17000.h5
# 23/23 [==============================] - 95s 4s/step - loss: 1.5231 - categorical_accuracy: 0.4118 - val_loss: 1.8348 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 2/2
# 23/23 [==============================] - ETA: 0s - loss: 0.9630 - categorical_accuracy: 0.6199
# Epoch 2: val_loss did not improve from 1.83475
# 23/23 [==============================] - 92s 4s/step - loss: 0.9630 - categorical_accuracy: 0.6199 - val_loss: 4.3929 - val_categorical_accuracy: 0.1100 - lr: 0.0010

# %% [raw]
# from the above "image resolution" and number of frames in sequence has more impact on training time than batch size.
#
# We can consider the Batch Size around 15-40.
#
# We will change the resoulution 160 * 160, 120 * 120 according the model performance

# %% [raw]
# Model 1
# Base Model - Batch Size = 40 and No. of Epochs = 20

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=20)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_20 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_30 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_21 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_31 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_22 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_32 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_23 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_33 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 12800)             0
#
#  dense_15 (Dense)            (None, 64)                819264
#
#  batch_normalization_34 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  batch_normalization_35 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 17/17 [==============================] - ETA: 0s - loss: 1.5654 - categorical_accuracy: 0.4042
# Epoch 1: val_loss improved from inf to 2.31288, saving model to model_init_2022-05-1623_05_46.550180/model-00001-1.56543-0.40422-2.31288-0.21000.h5
# 17/17 [==============================] - 118s 7s/step - loss: 1.5654 - categorical_accuracy: 0.4042 - val_loss: 2.3129 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 17/17 [==============================] - ETA: 0s - loss: 0.9036 - categorical_accuracy: 0.6290
# Epoch 2: val_loss did not improve from 2.31288
# 17/17 [==============================] - 116s 7s/step - loss: 0.9036 - categorical_accuracy: 0.6290 - val_loss: 2.8513 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 3/20
# 17/17 [==============================] - ETA: 0s - loss: 0.6994 - categorical_accuracy: 0.7406
# Epoch 3: val_loss did not improve from 2.31288
# 17/17 [==============================] - 111s 7s/step - loss: 0.6994 - categorical_accuracy: 0.7406 - val_loss: 3.5569 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 4/20
# 17/17 [==============================] - ETA: 0s - loss: 0.4577 - categorical_accuracy: 0.8462
# Epoch 4: val_loss did not improve from 2.31288
# 17/17 [==============================] - 115s 7s/step - loss: 0.4577 - categorical_accuracy: 0.8462 - val_loss: 3.4557 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 5/20
# 17/17 [==============================] - ETA: 0s - loss: 0.3483 - categorical_accuracy: 0.8839
# Epoch 5: val_loss did not improve from 2.31288
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 17/17 [==============================] - 116s 7s/step - loss: 0.3483 - categorical_accuracy: 0.8839 - val_loss: 3.9963 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 6/20
# 17/17 [==============================] - ETA: 0s - loss: 0.2353 - categorical_accuracy: 0.9427
# Epoch 6: val_loss did not improve from 2.31288
# 17/17 [==============================] - 112s 7s/step - loss: 0.2353 - categorical_accuracy: 0.9427 - val_loss: 3.9547 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 7/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.9638
# Epoch 7: val_loss did not improve from 2.31288
# 17/17 [==============================] - 116s 7s/step - loss: 0.1783 - categorical_accuracy: 0.9638 - val_loss: 3.7532 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 8/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1885 - categorical_accuracy: 0.9517
# Epoch 8: val_loss did not improve from 2.31288
# 17/17 [==============================] - 114s 7s/step - loss: 0.1885 - categorical_accuracy: 0.9517 - val_loss: 3.7023 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 9/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1465 - categorical_accuracy: 0.9713
# Epoch 9: val_loss did not improve from 2.31288
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 17/17 [==============================] - 112s 7s/step - loss: 0.1465 - categorical_accuracy: 0.9713 - val_loss: 3.5548 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 10/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1268 - categorical_accuracy: 0.9789
# Epoch 10: val_loss did not improve from 2.31288
# 17/17 [==============================] - 115s 7s/step - loss: 0.1268 - categorical_accuracy: 0.9789 - val_loss: 3.7943 - val_categorical_accuracy: 0.2400 - lr: 4.0000e-05
# Epoch 11/20
# 17/17 [==============================] - ETA: 0s - loss: 0.1403 - categorical_accuracy: 0.9668
# Epoch 11: val_loss did not improve from 2.31288
# 17/17 [==============================] - 115s 7s/step - loss: 0.1403 - categorical_accuracy: 0.9668 - val_loss: 3.7341 - val_categorical_accuracy: 0.2200 - lr: 4.0000e-05
# Epoch 11: early stopping

# %%
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].grid()
    axes[0].legend(['loss','val_loss'])
    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].grid()
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [raw]
# - val_loss did not improve from 2.31288 and early stopping at 11/20 epoch

# %% [raw]
# Model 2
# Adding dropout layers - Batch Size = 20 and No. of Epochs = 25

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=25)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_24 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_24 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_36 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_24 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_25 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_25 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_37 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_25 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_26 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_26 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_38 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_26 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_27 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_27 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_39 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_27 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 12800)             0
#
#  dense_18 (Dense)            (None, 256)               3277056
#
#  batch_normalization_40 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_19 (Dense)            (None, 256)               65792
#
#  batch_normalization_41 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_20 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 2.0355 - categorical_accuracy: 0.3597
# Epoch 1: val_loss improved from inf to 5.18377, saving model to model_init_2022-05-1623_26_53.103504/model-00001-2.03550-0.35973-5.18377-0.21000.h5
# 34/34 [==============================] - 218s 7s/step - loss: 2.0355 - categorical_accuracy: 0.3597 - val_loss: 5.1838 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.4673 - categorical_accuracy: 0.4834
# Epoch 2: val_loss did not improve from 5.18377
# 34/34 [==============================] - 216s 7s/step - loss: 1.4673 - categorical_accuracy: 0.4834 - val_loss: 7.0757 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2048 - categorical_accuracy: 0.9291
# Epoch 22: val_loss did not improve from 0.47373
# 34/34 [==============================] - 213s 6s/step - loss: 0.2048 - categorical_accuracy: 0.9291 - val_loss: 0.5109 - val_categorical_accuracy: 0.8500 - lr: 2.0000e-04
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.1637 - categorical_accuracy: 0.9495
# Epoch 23: val_loss did not improve from 0.47373
# 34/34 [==============================] - 210s 6s/step - loss: 0.1637 - categorical_accuracy: 0.9495 - val_loss: 0.6329 - val_categorical_accuracy: 0.8300 - lr: 2.0000e-04
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2007 - categorical_accuracy: 0.9299
# Epoch 24: val_loss improved from 0.47373 to 0.36864, saving model to model_init_2022-05-1623_26_53.103504/model-00024-0.20068-0.92986-0.36864-0.89000.h5
# 34/34 [==============================] - 209s 6s/step - loss: 0.2007 - categorical_accuracy: 0.9299 - val_loss: 0.3686 - val_categorical_accuracy: 0.8900 - lr: 2.0000e-04
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.1823 - categorical_accuracy: 0.9253
# Epoch 25: val_loss did not improve from 0.36864
# 34/34 [==============================] - 211s 6s/step - loss: 0.1823 - categorical_accuracy: 0.9253 - val_loss: 0.4707 - val_categorical_accuracy: 0.8900 - lr: 2.0000e-04

# %%
plot(history_model2)

# %% [raw]
# We can see val_loss did not improve from 0.368
# Seems overfitting
# Training accuracy 0.9193
# Validation accuracy 0.8400

# %% [raw]
# Model 3
# Reduce filter size to (2,2,2) and image res to 120 x 120, - Batch Size = 30 and No. of Epochs = 25

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_28 (Conv3D)          (None, 16, 120, 120, 16)  400
#
#  activation_28 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_42 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_28 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_29 (Conv3D)          (None, 8, 60, 60, 32)     4128
#
#  activation_29 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_43 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_29 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_30 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_30 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_44 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_30 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_31 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_31 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_45 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_31 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_7 (Flatten)         (None, 6272)              0
#
#  dense_21 (Dense)            (None, 256)               1605888
#
#  batch_normalization_46 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 256)               65792
#
#  batch_normalization_47 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 23/23 [==============================] - ETA: 0s - loss: 2.0829 - categorical_accuracy: 0.3401
# Epoch 1: val_loss improved from inf to 1.88376, saving model to model_init_2022-05-1700_55_03.766318/model-00001-2.08293-0.34012-1.88376-0.16000.h5
# 23/23 [==============================] - 151s 7s/step - loss: 2.0829 - categorical_accuracy: 0.3401 - val_loss: 1.8838 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss: 1.3635 - categorical_accuracy: 0.5173
# Epoch 2: val_loss did not improve from 1.88376
# 23/23 [==============================] - 148s 7s/step - loss: 1.3635 - categorical_accuracy: 0.5173 - val_loss: 2.8747 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 3/25
# 23/23 [==============================] - ETA: 0s - loss: 1.1477 - categorical_accuracy: 0.5920
# Epoch 3: val_loss did not improve from 1.88376
# 23/23 [==============================] - 148s 7s/step - loss: 1.1477 - categorical_accuracy: 0.5920 - val_loss: 3.7558 - val_categorical_accuracy: 0.1400 - lr: 2.0000e-04
# Epoch 4/25
# 23/23 [==============================] - ETA: 0s - loss: 1.0475 - categorical_accuracy: 0.6312
# Epoch 4: val_loss did not improve from 1.88376
# 23/23 [==============================] - 147s 7s/step - loss: 1.0475 - categorical_accuracy: 0.6312 - val_loss: 4.6367 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 5/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8841 - categorical_accuracy: 0.6802
# Epoch 5: val_loss did not improve from 1.88376
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 23/23 [==============================] - 149s 7s/step - loss: 0.8841 - categorical_accuracy: 0.6802 - val_loss: 5.1900 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8563 - categorical_accuracy: 0.6991
# Epoch 6: val_loss did not improve from 1.88376
# 23/23 [==============================] - 147s 7s/step - loss: 0.8563 - categorical_accuracy: 0.6991 - val_loss: 5.6343 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 7/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8087 - categorical_accuracy: 0.7164
# Epoch 7: val_loss did not improve from 1.88376
# 23/23 [==============================] - 149s 7s/step - loss: 0.8087 - categorical_accuracy: 0.7164 - val_loss: 5.6769 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 8/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7845 - categorical_accuracy: 0.7179
# Epoch 8: val_loss did not improve from 1.88376
# 23/23 [==============================] - 147s 7s/step - loss: 0.7845 - categorical_accuracy: 0.7179 - val_loss: 6.3223 - val_categorical_accuracy: 0.1800 - lr: 4.0000e-05
# Epoch 9/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7181 - categorical_accuracy: 0.7300
# Epoch 9: val_loss did not improve from 1.88376
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 23/23 [==============================] - 147s 7s/step - loss: 0.7181 - categorical_accuracy: 0.7300 - val_loss: 6.6338 - val_categorical_accuracy: 0.2000 - lr: 4.0000e-05
# Epoch 10/25
# 23/23 [==============================] - ETA: 0s - loss: 0.6992 - categorical_accuracy: 0.7406
# Epoch 10: val_loss did not improve from 1.88376
# 23/23 [==============================] - 148s 7s/step - loss: 0.6992 - categorical_accuracy: 0.7406 - val_loss: 6.6727 - val_categorical_accuracy: 0.2200 - lr: 8.0000e-06
# Epoch 11/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7594 - categorical_accuracy: 0.7225
# Epoch 11: val_loss did not improve from 1.88376
# 23/23 [==============================] - 147s 7s/step - loss: 0.7594 - categorical_accuracy: 0.7225 - val_loss: 6.1907 - val_categorical_accuracy: 0.2100 - lr: 8.0000e-06
# Epoch 11: early stopping

# %%
plot(history_model3)

# %% [raw]
# Early stopping at epoch 11/25
# No improvements seen

# %% [raw]
# Model 4 -
# AddingAdditional layers - Batch Size = 20 and No. of Epochs = 25

# %%
class ModelConv3D4(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4=ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d4_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_32 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_32 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_48 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  conv3d_33 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_33 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_49 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_32 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_34 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_34 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_50 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  conv3d_35 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_35 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_51 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_33 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_36 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_36 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_52 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  conv3d_37 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_37 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_53 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_34 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_38 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_38 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_54 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  conv3d_39 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_39 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_55 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_35 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_8 (Flatten)         (None, 6272)              0
#
#  dense_24 (Dense)            (None, 256)               1605888
#
#  batch_normalization_56 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 256)               65792
#
#  batch_normalization_57 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 2556533
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 2.0484 - categorical_accuracy: 0.3326
# Epoch 1: val_loss improved from inf to 2.28360, saving model to model_init_2022-05-1701_22_18.973780/model-00001-2.04840-0.33258-2.28360-0.26000.h5
# 34/34 [==============================] - 153s 4s/step - loss: 2.0484 - categorical_accuracy: 0.3326 - val_loss: 2.2836 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.5515 - categorical_accuracy: 0.4683
# Epoch 2: val_loss did not improve from 2.28360
# 34/34 [==============================] - 148s 4s/step - loss: 1.5515 - categorical_accuracy: 0.4683 - val_loss: 3.3022 - val_categorical_accuracy: 0.1300 - lr: 0.0010
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1049 - categorical_accuracy: 0.5935
# Epoch 3: val_loss did not improve from 2.28360
# 34/34 [==============================] - 149s 5s/step - loss: 1.1049 - categorical_accuracy: 0.5935 - val_loss: 2.8225 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8090 - categorical_accuracy: 0.6953
# Epoch 4: val_loss did not improve from 2.28360
# 34/34 [==============================] - 146s 4s/step - loss: 0.8090 - categorical_accuracy: 0.6953 - val_loss: 4.1696 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7108 - categorical_accuracy: 0.7504
# Epoch 5: val_loss did not improve from 2.28360
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 151s 5s/step - loss: 0.7108 - categorical_accuracy: 0.7504 - val_loss: 4.0800 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6533 - categorical_accuracy: 0.7617
# Epoch 6: val_loss did not improve from 2.28360
# 34/34 [==============================] - 150s 5s/step - loss: 0.6533 - categorical_accuracy: 0.7617 - val_loss: 4.2983 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5335 - categorical_accuracy: 0.8069
# Epoch 7: val_loss did not improve from 2.28360
# 34/34 [==============================] - 151s 5s/step - loss: 0.5335 - categorical_accuracy: 0.8069 - val_loss: 3.3833 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4652 - categorical_accuracy: 0.8348
# Epoch 8: val_loss did not improve from 2.28360
# 34/34 [==============================] - 152s 5s/step - loss: 0.4652 - categorical_accuracy: 0.8348 - val_loss: 3.8528 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4050 - categorical_accuracy: 0.8544
# Epoch 9: val_loss did not improve from 2.28360
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 150s 5s/step - loss: 0.4050 - categorical_accuracy: 0.8544 - val_loss: 2.7343 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3760 - categorical_accuracy: 0.8620
# Epoch 10: val_loss did not improve from 2.28360
# 34/34 [==============================] - 149s 4s/step - loss: 0.3760 - categorical_accuracy: 0.8620 - val_loss: 2.3175 - val_categorical_accuracy: 0.3000 - lr: 4.0000e-05
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3679 - categorical_accuracy: 0.8658
# Epoch 11: val_loss improved from 2.28360 to 1.89564, saving model to model_init_2022-05-1701_22_18.973780/model-00011-0.36786-0.86576-1.89564-0.35000.h5
# 34/34 [==============================] - 149s 4s/step - loss: 0.3679 - categorical_accuracy: 0.8658 - val_loss: 1.8956 - val_categorical_accuracy: 0.3500 - lr: 4.0000e-05
# Epoch 12/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3197 - categorical_accuracy: 0.8824
# Epoch 12: val_loss improved from 1.89564 to 1.57512, saving model to model_init_2022-05-1701_22_18.973780/model-00012-0.31975-0.88235-1.57512-0.46000.h5
# 34/34 [==============================] - 149s 5s/step - loss: 0.3197 - categorical_accuracy: 0.8824 - val_loss: 1.5751 - val_categorical_accuracy: 0.4600 - lr: 4.0000e-05
# Epoch 13/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3506 - categorical_accuracy: 0.8582
# Epoch 13: val_loss improved from 1.57512 to 1.10697, saving model to model_init_2022-05-1701_22_18.973780/model-00013-0.35055-0.85822-1.10697-0.59000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.3506 - categorical_accuracy: 0.8582 - val_loss: 1.1070 - val_categorical_accuracy: 0.5900 - lr: 4.0000e-05
# Epoch 14/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3019 - categorical_accuracy: 0.8861
# Epoch 14: val_loss improved from 1.10697 to 1.00231, saving model to model_init_2022-05-1701_22_18.973780/model-00014-0.30187-0.88612-1.00231-0.65000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.3019 - categorical_accuracy: 0.8861 - val_loss: 1.0023 - val_categorical_accuracy: 0.6500 - lr: 4.0000e-05
# Epoch 15/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3050 - categorical_accuracy: 0.8959
# Epoch 15: val_loss improved from 1.00231 to 0.77783, saving model to model_init_2022-05-1701_22_18.973780/model-00015-0.30505-0.89593-0.77783-0.70000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.3050 - categorical_accuracy: 0.8959 - val_loss: 0.7778 - val_categorical_accuracy: 0.7000 - lr: 4.0000e-05
# Epoch 16/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3221 - categorical_accuracy: 0.8846
# Epoch 16: val_loss improved from 0.77783 to 0.56539, saving model to model_init_2022-05-1701_22_18.973780/model-00016-0.32210-0.88462-0.56539-0.78000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.3221 - categorical_accuracy: 0.8846 - val_loss: 0.5654 - val_categorical_accuracy: 0.7800 - lr: 4.0000e-05
# Epoch 17/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3483 - categorical_accuracy: 0.8710
# Epoch 17: val_loss improved from 0.56539 to 0.45767, saving model to model_init_2022-05-1701_22_18.973780/model-00017-0.34832-0.87104-0.45767-0.81000.h5
# 34/34 [==============================] - 149s 4s/step - loss: 0.3483 - categorical_accuracy: 0.8710 - val_loss: 0.4577 - val_categorical_accuracy: 0.8100 - lr: 4.0000e-05
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2954 - categorical_accuracy: 0.8959
# Epoch 18: val_loss improved from 0.45767 to 0.38084, saving model to model_init_2022-05-1701_22_18.973780/model-00018-0.29535-0.89593-0.38084-0.88000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.2954 - categorical_accuracy: 0.8959 - val_loss: 0.3808 - val_categorical_accuracy: 0.8800 - lr: 4.0000e-05
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3139 - categorical_accuracy: 0.8922
# Epoch 19: val_loss improved from 0.38084 to 0.32320, saving model to model_init_2022-05-1701_22_18.973780/model-00019-0.31394-0.89216-0.32320-0.91000.h5
# 34/34 [==============================] - 148s 4s/step - loss: 0.3139 - categorical_accuracy: 0.8922 - val_loss: 0.3232 - val_categorical_accuracy: 0.9100 - lr: 4.0000e-05
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3094 - categorical_accuracy: 0.8793
# Epoch 20: val_loss improved from 0.32320 to 0.26862, saving model to model_init_2022-05-1701_22_18.973780/model-00020-0.30944-0.87934-0.26862-0.94000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.3094 - categorical_accuracy: 0.8793 - val_loss: 0.2686 - val_categorical_accuracy: 0.9400 - lr: 4.0000e-05
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2843 - categorical_accuracy: 0.8959
# Epoch 21: val_loss did not improve from 0.26862
# 34/34 [==============================] - 148s 4s/step - loss: 0.2843 - categorical_accuracy: 0.8959 - val_loss: 0.3244 - val_categorical_accuracy: 0.8800 - lr: 4.0000e-05
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2912 - categorical_accuracy: 0.8952
# Epoch 22: val_loss did not improve from 0.26862
# 34/34 [==============================] - 151s 5s/step - loss: 0.2912 - categorical_accuracy: 0.8952 - val_loss: 0.3594 - val_categorical_accuracy: 0.9000 - lr: 4.0000e-05
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.3352 - categorical_accuracy: 0.8846
# Epoch 23: val_loss did not improve from 0.26862
# 34/34 [==============================] - 150s 5s/step - loss: 0.3352 - categorical_accuracy: 0.8846 - val_loss: 0.3685 - val_categorical_accuracy: 0.8900 - lr: 4.0000e-05
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2569 - categorical_accuracy: 0.8959
# Epoch 24: val_loss improved from 0.26862 to 0.26789, saving model to model_init_2022-05-1701_22_18.973780/model-00024-0.25687-0.89593-0.26789-0.93000.h5
# 34/34 [==============================] - 151s 5s/step - loss: 0.2569 - categorical_accuracy: 0.8959 - val_loss: 0.2679 - val_categorical_accuracy: 0.9300 - lr: 4.0000e-05
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.2584 - categorical_accuracy: 0.8967
# Epoch 25: val_loss did not improve from 0.26789
# 34/34 [==============================] - 150s 5s/step - loss: 0.2584 - categorical_accuracy: 0.8967 - val_loss: 0.3068 - val_categorical_accuracy: 0.9100 - lr: 4.0000e-05

# %%
plot(history_model4)

# %% [raw]
# With more layers we do see performance improvement. We get a best validation accuracy of 93% .

# %% [raw]
# Model 5
# Reducing the number of parameters

# %%
class ModelConv3D5(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d5=ModelConv3D5()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=100,image_width=100)
conv_3d5.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=20)
conv_3d5_model=conv_3d5.define_model(dense_neurons=128,dropout=0.25)
conv_3d5_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_40 (Conv3D)          (None, 16, 100, 100, 16)  1312
#
#  activation_40 (Activation)  (None, 16, 100, 100, 16)  0
#
#  batch_normalization_58 (Bat  (None, 16, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_36 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_41 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_41 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_59 (Bat  (None, 8, 50, 50, 32)    128
#  chNormalization)
#
#  max_pooling3d_37 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_42 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_42 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_60 (Bat  (None, 4, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_38 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_43 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  activation_43 (Activation)  (None, 2, 12, 12, 128)    0
#
#  batch_normalization_61 (Bat  (None, 2, 12, 12, 128)   512
#  chNormalization)
#
#  max_pooling3d_39 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_9 (Flatten)         (None, 4608)              0
#
#  dense_27 (Dense)            (None, 128)               589952
#
#  batch_normalization_62 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_28 (Dense)            (None, 128)               16512
#
#  batch_normalization_63 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_29 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 696,645
# Trainable params: 695,653
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", conv_3d5_model.count_params())
history_model5=conv_3d5.train_model(conv_3d5_model,augment_data=True)
# Out:
# Total Params: 696645
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.6899 - categorical_accuracy: 0.3891
# Epoch 1: val_loss improved from inf to 2.18794, saving model to model_init_2022-05-1702_24_54.813871/model-00001-1.68989-0.38914-2.18794-0.16000.h5
# 34/34 [==============================] - 145s 4s/step - loss: 1.6899 - categorical_accuracy: 0.3891 - val_loss: 2.1879 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0310 - categorical_accuracy: 0.6078
# Epoch 2: val_loss did not improve from 2.18794
# 34/34 [==============================] - 140s 4s/step - loss: 1.0310 - categorical_accuracy: 0.6078 - val_loss: 3.2442 - val_categorical_accuracy: 0.1200 - lr: 2.0000e-04
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8884 - categorical_accuracy: 0.6652
# Epoch 3: val_loss did not improve from 2.18794
# 34/34 [==============================] - 140s 4s/step - loss: 0.8884 - categorical_accuracy: 0.6652 - val_loss: 3.7457 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7646 - categorical_accuracy: 0.7119
# Epoch 4: val_loss did not improve from 2.18794
# 34/34 [==============================] - 143s 4s/step - loss: 0.7646 - categorical_accuracy: 0.7119 - val_loss: 4.6603 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6290 - categorical_accuracy: 0.7617
# Epoch 5: val_loss did not improve from 2.18794
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 143s 4s/step - loss: 0.6290 - categorical_accuracy: 0.7617 - val_loss: 5.2646 - val_categorical_accuracy: 0.1400 - lr: 2.0000e-04
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5630 - categorical_accuracy: 0.7881
# Epoch 6: val_loss did not improve from 2.18794
# 34/34 [==============================] - 142s 4s/step - loss: 0.5630 - categorical_accuracy: 0.7881 - val_loss: 5.5925 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5605 - categorical_accuracy: 0.8069
# Epoch 7: val_loss did not improve from 2.18794
# 34/34 [==============================] - 140s 4s/step - loss: 0.5605 - categorical_accuracy: 0.8069 - val_loss: 5.9047 - val_categorical_accuracy: 0.2000 - lr: 4.0000e-05
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5539 - categorical_accuracy: 0.8024
# Epoch 8: val_loss did not improve from 2.18794
# 34/34 [==============================] - 140s 4s/step - loss: 0.5539 - categorical_accuracy: 0.8024 - val_loss: 5.8898 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4959 - categorical_accuracy: 0.8183
# Epoch 9: val_loss did not improve from 2.18794
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 142s 4s/step - loss: 0.4959 - categorical_accuracy: 0.8183 - val_loss: 6.0074 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4964 - categorical_accuracy: 0.8281
# Epoch 10: val_loss did not improve from 2.18794
# 34/34 [==============================] - 142s 4s/step - loss: 0.4964 - categorical_accuracy: 0.8281 - val_loss: 5.3066 - val_categorical_accuracy: 0.2600 - lr: 8.0000e-06
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4906 - categorical_accuracy: 0.8311
# Epoch 11: val_loss did not improve from 2.18794
# 34/34 [==============================] - 142s 4s/step - loss: 0.4906 - categorical_accuracy: 0.8311 - val_loss: 4.5560 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 11: early stopping

# %%
plot(history_model5)

# %% [raw]
# Model 6 - Reducing the number of parameters again

# %%
class ModelConv3D6(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d6=ModelConv3D6()
conv_3d6.initialize_path(project_folder)
conv_3d6.initialize_image_properties(image_height=120,image_width=120)
conv_3d6.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d6_model=conv_3d6.define_model(dense_neurons=64,dropout=0.25)
conv_3d6_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 16, 120, 120, 16)  1312
#
#  activation_4 (Activation)   (None, 16, 120, 120, 16)  0
#
#  batch_normalization_6 (Batc  (None, 16, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 8, 60, 60, 16)    0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 8, 60, 60, 32)     13856
#
#  activation_5 (Activation)   (None, 8, 60, 60, 32)     0
#
#  batch_normalization_7 (Batc  (None, 8, 60, 60, 32)    128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 4, 30, 30, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 4, 30, 30, 64)     16448
#
#  activation_6 (Activation)   (None, 4, 30, 30, 64)     0
#
#  batch_normalization_8 (Batc  (None, 4, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 2, 15, 15, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 2, 15, 15, 128)    65664
#
#  activation_7 (Activation)   (None, 2, 15, 15, 128)    0
#
#  batch_normalization_9 (Batc  (None, 2, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 64)                401472
#
#  batch_normalization_10 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  batch_normalization_11 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 504,709
# Trainable params: 503,973
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d6_model.count_params())
history_model6=conv_3d6.train_model(conv_3d6_model,augment_data=True)
# Out:
# Total Params: 504709
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 2022-05-17 05:33:35.278027: I tensorflow/stream_executor/cuda/cuda_dnn.cc:379] Loaded cuDNN version 8303
# 2022-05-17 05:33:37.771474: I tensorflow/stream_executor/cuda/cuda_blas.cc:1804] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 34/34 [==============================] - ETA: 0s - loss: 1.7758 - categorical_accuracy: 0.3703
# Epoch 1: val_loss improved from inf to 1.76553, saving model to model_init_2022-05-1705_33_29.267913/model-00001-1.77582-0.37029-1.76553-0.16000.h5
# 34/34 [==============================] - 156s 5s/step - loss: 1.7758 - categorical_accuracy: 0.3703 - val_loss: 1.7655 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2249 - categorical_accuracy: 0.5445
# Epoch 2: val_loss did not improve from 1.76553
# 34/34 [==============================] - 155s 5s/step - loss: 1.2249 - categorical_accuracy: 0.5445 - val_loss: 2.2562 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9428 - categorical_accuracy: 0.6373
# Epoch 3: val_loss did not improve from 1.76553
# 34/34 [==============================] - 151s 5s/step - loss: 0.9428 - categorical_accuracy: 0.6373 - val_loss: 3.3392 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8166 - categorical_accuracy: 0.6787
# Epoch 4: val_loss did not improve from 1.76553
# 34/34 [==============================] - 148s 4s/step - loss: 0.8166 - categorical_accuracy: 0.6787 - val_loss: 4.3181 - val_categorical_accuracy: 0.0900 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7164 - categorical_accuracy: 0.7179
# Epoch 5: val_loss did not improve from 1.76553
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 149s 5s/step - loss: 0.7164 - categorical_accuracy: 0.7179 - val_loss: 4.3125 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5950 - categorical_accuracy: 0.7851
# Epoch 6: val_loss did not improve from 1.76553
# 34/34 [==============================] - 153s 5s/step - loss: 0.5950 - categorical_accuracy: 0.7851 - val_loss: 4.8777 - val_categorical_accuracy: 0.3200 - lr: 4.0000e-05
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5807 - categorical_accuracy: 0.7745
# Epoch 7: val_loss did not improve from 1.76553
# 34/34 [==============================] - 151s 5s/step - loss: 0.5807 - categorical_accuracy: 0.7745 - val_loss: 4.8764 - val_categorical_accuracy: 0.3000 - lr: 4.0000e-05
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5848 - categorical_accuracy: 0.7896
# Epoch 8: val_loss did not improve from 1.76553
# 34/34 [==============================] - 152s 5s/step - loss: 0.5848 - categorical_accuracy: 0.7896 - val_loss: 4.7402 - val_categorical_accuracy: 0.2400 - lr: 4.0000e-05
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5678 - categorical_accuracy: 0.7971
# Epoch 9: val_loss did not improve from 1.76553
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 152s 5s/step - loss: 0.5678 - categorical_accuracy: 0.7971 - val_loss: 4.7043 - val_categorical_accuracy: 0.2200 - lr: 4.0000e-05
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5375 - categorical_accuracy: 0.7949
# Epoch 10: val_loss did not improve from 1.76553
# 34/34 [==============================] - 150s 5s/step - loss: 0.5375 - categorical_accuracy: 0.7949 - val_loss: 4.4921 - val_categorical_accuracy: 0.2300 - lr: 8.0000e-06
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5429 - categorical_accuracy: 0.8024
# Epoch 11: val_loss did not improve from 1.76553
# 34/34 [==============================] - 150s 5s/step - loss: 0.5429 - categorical_accuracy: 0.8024 - val_loss: 3.8181 - val_categorical_accuracy: 0.2100 - lr: 8.0000e-06
# Epoch 11: early stopping

# %%
plot(history_model6)

# %% [raw]
# Model 7 - CNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        #model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
       # model.add(TimeDistributed(BatchNormalization()))
       # model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 18, 120, 120, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 18, 120, 120, 16)  64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 18, 60, 60, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 18, 60, 60, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 18, 60, 60, 32)   128
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 18, 30, 30, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 18, 30, 30, 64)   18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 18, 30, 30, 64)   256
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 18, 15, 15, 64)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 18, 15, 15, 128)  73856
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 18, 7, 7, 256)    295168
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 18, 7, 7, 256)    1024
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 18, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 18, 2304)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 128)               1245696
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,657,445
# Trainable params: 1,656,453
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model7=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1657445
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3898 - categorical_accuracy: 0.4072
# Epoch 1: val_loss improved from inf to 1.68288, saving model to model_init_2022-05-1706_50_49.436076/model-00001-1.38985-0.40724-1.68288-0.21000.h5
# 34/34 [==============================] - 173s 5s/step - loss: 1.3898 - categorical_accuracy: 0.4072 - val_loss: 1.6829 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0160 - categorical_accuracy: 0.6056
# Epoch 2: val_loss did not improve from 1.68288
# 34/34 [==============================] - 167s 5s/step - loss: 1.0160 - categorical_accuracy: 0.6056 - val_loss: 2.4391 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7714 - categorical_accuracy: 0.7097
# Epoch 3: val_loss did not improve from 1.68288
# 34/34 [==============================] - 165s 5s/step - loss: 0.7714 - categorical_accuracy: 0.7097 - val_loss: 2.7091 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7106 - categorical_accuracy: 0.7293
# Epoch 4: val_loss did not improve from 1.68288
# 34/34 [==============================] - 165s 5s/step - loss: 0.7106 - categorical_accuracy: 0.7293 - val_loss: 2.5993 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5774 - categorical_accuracy: 0.7919
# Epoch 5: val_loss did not improve from 1.68288
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 164s 5s/step - loss: 0.5774 - categorical_accuracy: 0.7919 - val_loss: 2.7913 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4067 - categorical_accuracy: 0.8552
# Epoch 6: val_loss did not improve from 1.68288
# 34/34 [==============================] - 165s 5s/step - loss: 0.4067 - categorical_accuracy: 0.8552 - val_loss: 2.5978 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3159 - categorical_accuracy: 0.9035
# Epoch 7: val_loss did not improve from 1.68288
# 34/34 [==============================] - 181s 5s/step - loss: 0.3159 - categorical_accuracy: 0.9035 - val_loss: 2.4059 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2803 - categorical_accuracy: 0.9057
# Epoch 8: val_loss did not improve from 1.68288
# 34/34 [==============================] - 191s 6s/step - loss: 0.2803 - categorical_accuracy: 0.9057 - val_loss: 2.2152 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2145 - categorical_accuracy: 0.9336
# Epoch 9: val_loss did not improve from 1.68288
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 194s 6s/step - loss: 0.2145 - categorical_accuracy: 0.9336 - val_loss: 2.4907 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1965 - categorical_accuracy: 0.9419
# Epoch 10: val_loss did not improve from 1.68288
# 34/34 [==============================] - 178s 5s/step - loss: 0.1965 - categorical_accuracy: 0.9419 - val_loss: 2.6095 - val_categorical_accuracy: 0.3400 - lr: 4.0000e-05
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1833 - categorical_accuracy: 0.9480
# Epoch 11: val_loss did not improve from 1.68288
# 34/34 [==============================] - 165s 5s/step - loss: 0.1833 - categorical_accuracy: 0.9480 - val_loss: 2.4866 - val_categorical_accuracy: 0.3600 - lr: 4.0000e-05
# Epoch 11: early stopping

# %%
plot(history_model7)

# %% [raw]
# Applying data augmentation

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:]) 
plt.show()

# %% [raw]
# Model 8 with Augmentation(3,3,3) Filter & 160x160 Image resolution

# %%
class ModelConv3D8(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d8=ModelConv3D8()
conv_3d8.initialize_path(project_folder)
conv_3d8.initialize_image_properties(image_height=160,image_width=160)
conv_3d8.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=20)
conv_3d8_model=conv_3d8.define_model(dense_neurons=256,dropout=0.5)
conv_3d8_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 20, 160, 160, 16)  1312
#
#  activation_8 (Activation)   (None, 20, 160, 160, 16)  0
#
#  batch_normalization_17 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 10, 80, 80, 16)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_9 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_18 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_10 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_19 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_11 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_20 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_8 (Dense)             (None, 256)               3277056
#
#  batch_normalization_21 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 256)               65792
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d8_model.count_params())
history_model8=conv_3d8.train_model(conv_3d8_model,augment_data=True)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.9883 - categorical_accuracy: 0.3763
# Epoch 1: saving model to model_init_2022-05-1707_26_56.059327/model-00001-1.98831-0.37632-2.28272-0.18000.h5
# 34/34 [==============================] - 230s 7s/step - loss: 1.9883 - categorical_accuracy: 0.3763 - val_loss: 2.2827 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4081 - categorical_accuracy: 0.5287
# Epoch 2: saving model to model_init_2022-05-1707_26_56.059327/model-00002-1.40809-0.52866-3.82970-0.15000.h5
# 34/34 [==============================] - 226s 7s/step - loss: 1.4081 - categorical_accuracy: 0.5287 - val_loss: 3.8297 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.
- lr: 8.0000e-06
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5522 - categorical_accuracy: 0.7941
# Epoch 14: saving model to model_init_2022-05-1707_26_56.059327/model-00014-0.55223-0.79412-2.69219-0.41000.h5
# 34/34 [==============================] - 213s 6s/step - loss: 0.5522 - categorical_accuracy: 0.7941 - val_loss: 2.6922 - val_categorical_accuracy: 0.4100 - lr: 1.6000e-06
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4963 - categorical_accuracy: 0.8190
# Epoch 15: saving model to model_init_2022-05-1707_26_56.059327/model-00015-0.49631-0.81900-1.78324-0.49000.h5
# 34/34 [==============================] - 214s 6s/step - loss: 0.4963 - categorical_accuracy: 0.8190 - val_loss: 1.7832 - val_categorical_accuracy: 0.4900 - lr: 1.6000e-06
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5417 - categorical_accuracy: 0.8069
# Epoch 16: saving model to model_init_2022-05-1707_26_56.059327/model-00016-0.54166-0.80694-1.42597-0.57000.h5
# 34/34 [==============================] - 212s 6s/step - loss: 0.5417 - categorical_accuracy: 0.8069 - val_loss: 1.4260 - val_categorical_accuracy: 0.5700 - lr: 1.6000e-06
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5086 - categorical_accuracy: 0.8130
# Epoch 17: saving model to model_init_2022-05-1707_26_56.059327/model-00017-0.50855-0.81297-0.96643-0.70000.h5
# 34/34 [==============================] - 214s 6s/step - loss: 0.5086 - categorical_accuracy: 0.8130 - val_loss: 0.9664 - val_categorical_accuracy: 0.7000 - lr: 1.6000e-06
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5352 - categorical_accuracy: 0.8032
# Epoch 18: saving model to model_init_2022-05-1707_26_56.059327/model-00018-0.53517-0.80317-0.97737-0.72000.h5
# 34/34 [==============================] - 213s 6s/step - loss: 0.5352 - categorical_accuracy: 0.8032 - val_loss: 0.9774 - val_categorical_accuracy: 0.7200 - lr: 1.6000e-06
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5238 - categorical_accuracy: 0.8130
# Epoch 19: saving model to model_init_2022-05-1707_26_56.059327/model-00019-0.52384-0.81297-0.77398-0.73000.h5
# 34/34 [==============================] - 212s 6s/step - loss: 0.5238 - categorical_accuracy: 0.8130 - val_loss: 0.7740 - val_categorical_accuracy: 0.7300 - lr: 1.6000e-06
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4568 - categorical_accuracy: 0.8258
# Epoch 20: saving model to model_init_2022-05-1707_26_56.059327/model-00020-0.45683-0.82579-0.63469-0.81000.h5
# 34/34 [==============================] - 213s 6s/step - loss: 0.4568 - categorical_accuracy: 0.8258 - val_loss: 0.6347 - val_categorical_accuracy: 0.8100 - lr: 1.6000e-06

# %%
plot(history_model8)

# %% [raw]
# Highest validation accuracy so far  0.8100

# %% [raw]
# Model 9 with Augmentation (2,2,2) Filter & 120x120 Image resolution

# %%
class ModelConv3D9(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d9=ModelConv3D9()
conv_3d9.initialize_path(project_folder)
conv_3d9.initialize_image_properties(image_height=120,image_width=120)
conv_3d9.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d9_model=conv_3d9.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d9_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 16, 120, 120, 16)  400
#
#  activation_12 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_23 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 8, 60, 60, 32)     4128
#
#  activation_13 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_24 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_14 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_25 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_15 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_26 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_11 (Dense)            (None, 256)               1605888
#
#  batch_normalization_27 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d9_model.count_params())
history_model9=conv_3d9.train_model(conv_3d9_model,augment_data=True)
# Out:
# Total Params: 1762613
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 23/23 [==============================] - ETA: 0s - loss: 2.1809 - categorical_accuracy: 0.3228
# Epoch 1: saving model to model_init_2022-05-1708_40_01.967902/model-00001-2.18087-0.32278-1.75915-0.16000.h5
# 23/23 [==============================] - 149s 7s/step - loss: 2.1809 - categorical_accuracy: 0.3228 - val_loss: 1.7591 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss:
25
# 23/23 [==============================] - ETA: 0s - loss: 0.7416 - categorical_accuracy: 0.7300
# Epoch 22: saving model to model_init_2022-05-1708_40_01.967902/model-00022-0.74155-0.73002-1.46818-0.49000.h5
# 23/23 [==============================] - 149s 7s/step - loss: 0.7416 - categorical_accuracy: 0.7300 - val_loss: 1.4682 - val_categorical_accuracy: 0.4900 - lr: 3.2000e-07
# Epoch 23/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7500 - categorical_accuracy: 0.7308
# Epoch 23: saving model to model_init_2022-05-1708_40_01.967902/model-00023-0.74999-0.73077-1.30104-0.55000.h5
# 23/23 [==============================] - 147s 7s/step - loss: 0.7500 - categorical_accuracy: 0.7308 - val_loss: 1.3010 - val_categorical_accuracy: 0.5500 - lr: 3.2000e-07
# Epoch 24/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7206 - categorical_accuracy: 0.7353
# Epoch 24: saving model to model_init_2022-05-1708_40_01.967902/model-00024-0.72058-0.73529-0.86013-0.67000.h5
# 23/23 [==============================] - 144s 7s/step - loss: 0.7206 - categorical_accuracy: 0.7353 - val_loss: 0.8601 - val_categorical_accuracy: 0.6700 - lr: 3.2000e-07
# Epoch 25/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7148 - categorical_accuracy: 0.7353
# Epoch 25: saving model to model_init_2022-05-1708_40_01.967902/model-00025-0.71477-0.73529-0.91491-0.67000.h5
# 23/23 [==============================] - 147s 7s/step - loss: 0.7148 - categorical_accuracy: 0.7353 - val_loss: 0.9149 - val_categorical_accuracy: 0.6700 - lr: 3.2000e-07

# %%
plot(history_model9)

# %% [raw]
# best training and validation accuray is 0.7353 and 0.6700

# %% [raw]
# Model 10 with Augmentation Reducing network parameters

# %%
class ModelConv3D10(ModelBuilderMoreAugmentation):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d10=ModelConv3D10()
conv_3d10.initialize_path(project_folder)
conv_3d10.initialize_image_properties(image_height=100,image_width=100)
conv_3d10.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d10_model=conv_3d10.define_model(dense_neurons=128,dropout=0.25)
conv_3d10_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_16 (Conv3D)          (None, 16, 100, 100, 16)  1312
#
#  activation_16 (Activation)  (None, 16, 100, 100, 16)  0
#
#  batch_normalization_29 (Bat  (None, 16, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_17 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_30 (Bat  (None, 8, 50, 50, 32)    128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_18 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_31 (Bat  (None, 4, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  activation_19 (Activation)  (None, 2, 12, 12, 128)    0
#
#  batch_normalization_32 (Bat  (None, 2, 12, 12, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 4608)              0
#
#  dense_14 (Dense)            (None, 128)               589952
#
#  batch_normalization_33 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 128)               16512
#
#  batch_normalization_34 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 696,645
# Trainable params: 695,653
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", conv_3d10_model.count_params())
history_model10=conv_3d10.train_model(conv_3d10_model,augment_data=True)
# Out:
# Total Params: 696645
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.7529 - categorical_accuracy: 0.3627
# Epoch 1: saving model to model_init_2022-05-1709_41_07.702219/model-00001-1.75293-0.36275-1.87605-0.29000.h5
# 34/34 [==============================] - 145s 4s/step - loss: 1.7529 - categorical_accuracy: 0.3627 - val_loss: 1.8761 - val_categorical_accuracy: 0.2900 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1229 - categorical_accuracy: 0.5739
# Epoch 2: saving model to model_init_2022-05-1709_41_07.702219/model-00002-1.12293-0.57391-2.63355-0.21000.h5
# 34/34 [==============================] - 143s 4s/step - loss: 1.1229 - categorical_accuracy: 0.5739 - val_loss: 2.6335 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9087 - categorical_accuracy: 0.6471
# Epoch 3: saving model to model_init_2022-05-1709_41_07.702219/model-00003-0.90872-0.64706-3.73797-0.18000.h5
# 34/34 [==============================] - 144s 4s/step - loss: 0.9087 - categorical_accuracy: 0.6471 - val_loss: 3.7380 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8062 - categorical_accuracy: 0.6991
# Epoch 4: saving model to model_init_2022-05-1709_41_07.702219/model-00004-0.80621-0.69910-4.61873-0.21000.h5
# 34/34 [==============================] - 144s 4s/step - loss: 0.8062 - categorical_accuracy: 0.6991 - val_loss: 4.6187 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.
- lr: 1.6000e-06
# Epoch 16/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5062 - categorical_accuracy: 0.8047
# Epoch 16: saving model to model_init_2022-05-1709_41_07.702219/model-00016-0.50617-0.80468-1.77849-0.43000.h5
# 34/34 [==============================] - 147s 4s/step - loss: 0.5062 - categorical_accuracy: 0.8047 - val_loss: 1.7785 - val_categorical_accuracy: 0.4300 - lr: 1.6000e-06
# Epoch 17/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5022 - categorical_accuracy: 0.8047
# Epoch 17: saving model to model_init_2022-05-1709_41_07.702219/model-00017-0.50215-0.80468-1.47517-0.52000.h5
# 34/34 [==============================] - 142s 4s/step - loss: 0.5022 - categorical_accuracy: 0.8047 - val_loss: 1.4752 - val_categorical_accuracy: 0.5200 - lr: 1.6000e-06
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5173 - categorical_accuracy: 0.8077
# Epoch 18: saving model to model_init_2022-05-1709_41_07.702219/model-00018-0.51728-0.80769-1.23750-0.61000.h5
# 34/34 [==============================] - 143s 4s/step - loss: 0.5173 - categorical_accuracy: 0.8077 - val_loss: 1.2375 - val_categorical_accuracy: 0.6100 - lr: 1.6000e-06
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5235 - categorical_accuracy: 0.7919
# Epoch 19: saving model to model_init_2022-05-1709_41_07.702219/model-00019-0.52351-0.79186-1.12141-0.61000.h5
# 34/34 [==============================] - 145s 4s/step - loss: 0.5235 - categorical_accuracy: 0.7919 - val_loss: 1.1214 - val_categorical_accuracy: 0.6100 - lr: 1.6000e-06
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5011 - categorical_accuracy: 0.8137
# Epoch 20: saving model to model_init_2022-05-1709_41_07.702219/model-00020-0.50111-0.81373-0.87249-0.70000.h5
# 34/34 [==============================] - 145s 4s/step - loss: 0.5011 - categorical_accuracy: 0.8137 - val_loss: 0.8725 - val_categorical_accuracy: 0.7000 - lr: 1.6000e-06
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4618 - categorical_accuracy: 0.8281
# Epoch 21: saving model to model_init_2022-05-1709_41_07.702219/model-00021-0.46178-0.82805-0.86141-0.73000.h5
# 34/34 [==============================] - 144s 4s/step - loss: 0.4618 - categorical_accuracy: 0.8281 - val_loss: 0.8614 - val_categorical_accuracy: 0.7300 - lr: 1.6000e-06
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4966 - categorical_accuracy: 0.8107
# Epoch 22: saving model to model_init_2022-05-1709_41_07.702219/model-00022-0.49661-0.81071-0.81025-0.74000.h5
# 34/34 [==============================] - 143s 4s/step - loss: 0.4966 - categorical_accuracy: 0.8107 - val_loss: 0.8102 - val_categorical_accuracy: 0.7400 - lr: 1.6000e-06
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5324 - categorical_accuracy: 0.8039
# Epoch 23: saving model to model_init_2022-05-1709_41_07.702219/model-00023-0.53236-0.80392-0.82803-0.73000.h5
# 34/34 [==============================] - 142s 4s/step - loss: 0.5324 - categorical_accuracy: 0.8039 - val_loss: 0.8280 - val_categorical_accuracy: 0.7300 - lr: 1.6000e-06
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5455 - categorical_accuracy: 0.7903
# Epoch 24: saving model to model_init_2022-05-1709_41_07.702219/model-00024-0.54555-0.79035-0.71956-0.74000.h5
# 34/34 [==============================] - 142s 4s/step - loss: 0.5455 - categorical_accuracy: 0.7903 - val_loss: 0.7196 - val_categorical_accuracy: 0.7400 - lr: 1.6000e-06
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4894 - categorical_accuracy: 0.8152
# Epoch 25: saving model to model_init_2022-05-1709_41_07.702219/model-00025-0.48943-0.81523-0.63411-0.78000.h5
# 34/34 [==============================] - 144s 4s/step - loss: 0.4894 - categorical_accuracy: 0.8152 - val_loss: 0.6341 - val_categorical_accuracy: 0.7800 - lr: 1.6000e-06

# %%
plot(history_model10)

# %% [raw]
# best training accuracy is  0.8152 and validation  0.7800

# %% [raw]
# Model 11 with Augmentation CNN LSTM with GRU

# %%
class RNNCNN2(ModelBuilderMoreAugmentation):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        

        model.add(TimeDistributed(Flatten()))


        model.add(GRU(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn2=RNNCNN2()
rnn_cnn2.initialize_path(project_folder)
rnn_cnn2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn2.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn2_model=rnn_cnn2.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn2_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_16 (TimeDi  (None, 18, 120, 120, 16)  448
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 18, 120, 120, 16)  64
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 18, 60, 60, 16)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 18, 60, 60, 32)   4640
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 18, 60, 60, 32)   128
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 18, 30, 30, 32)   0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 18, 30, 30, 64)   18496
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 18, 30, 30, 64)   256
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 18, 15, 15, 64)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 18, 15, 15, 128)  73856
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_28 (TimeDi  (None, 18, 6272)         0
#  stributed)
#
#  gru (GRU)                   (None, 128)               2458368
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 128)               16512
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 2,573,925
# Trainable params: 2,573,445
# Non-trainable params: 480
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn2_model.count_params())
history_model11=rnn_cnn2.train_model(rnn_cnn2_model,augment_data=True)
# Out:
# Total Params: 2573925
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3847 - categorical_accuracy: 0.4110
# Epoch 1: saving model to model_init_2022-05-1710_41_14.219633/model-00001-1.38473-0.41101-1.63771-0.22000.h5
# 34/34 [==============================] - 169s 5s/step - loss: 1.3847 - categorical_accuracy: 0.4110 - val_loss: 1.6377 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8763 - categorical_accuracy: 0.6629
# Epoch 2: saving model to model_init_2022-05-1710_41_14.219633/model-00002-0.87626-0.66290-2.09535-0.19000.h5
# 34/34 [==============================] - 164s 5s/step - loss: 0.8763 - categorical_accuracy: 0.6629 - val_loss: 2.0953 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6798 - categorical_accuracy: 0.7504
# Epoch 3: saving model to model_init_2022-05-1710_41_14.219633/model-00003-0.67977-0.75038-2.20155-0.27000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.6798 - categorical_accuracy: 0.7504 - val_loss: 2.2016 - val_categorical_accuracy: 0.2700 - lr: 2.0000e-04
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5575 - categorical_accuracy: 0.8077
# Epoch 4: saving model to model_init_2022-05-1710_41_14.219633/model-00004-0.55752-0.80769-2.74911-0.19000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.5575 - categorical_accuracy: 0.8077 - val_loss: 2.7491 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4064 - categorical_accuracy: 0.8710
# Epoch 5: saving model to model_init_2022-05-1710_41_14.219633/model-00005-0.40636-0.87104-2.87951-0.21000.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 163s 5s/step - loss: 0.4064 - categorical_accuracy: 0.8710 - val_loss: 2.8795 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3294 - categorical_accuracy: 0.9050
# Epoch 6: saving model to model_init_2022-05-1710_41_14.219633/model-00006-0.32938-0.90498-2.94809-0.23000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.3294 - categorical_accuracy: 0.9050 - val_loss: 2.9481 - val_categorical_accuracy: 0.2300 - lr: 4.0000e-05
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2780 - categorical_accuracy: 0.9253
# Epoch 7: saving model to model_init_2022-05-1710_41_14.219633/model-00007-0.27803-0.92534-3.13482-0.22000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.2780 - categorical_accuracy: 0.9253 - val_loss: 3.1348 - val_categorical_accuracy: 0.2200 - lr: 4.0000e-05
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2715 - categorical_accuracy: 0.9238
# Epoch 8: saving model to model_init_2022-05-1710_41_14.219633/model-00008-0.27148-0.92383-3.21931-0.26000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.2715 - categorical_accuracy: 0.9238 - val_loss: 3.2193 - val_categorical_accuracy: 0.2600 - lr: 4.0000e-05
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2435 - categorical_accuracy: 0.9359
# Epoch 9: saving model to model_init_2022-05-1710_41_14.219633/model-00009-0.24348-0.93590-3.02710-0.30000.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 166s 5s/step - loss: 0.2435 - categorical_accuracy: 0.9359 - val_loss: 3.0271 - val_categorical_accuracy: 0.3000 - lr: 4.0000e-05
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2415 - categorical_accuracy: 0.9291
# Epoch 10: saving model to model_init_2022-05-1710_41_14.219633/model-00010-0.24155-0.92911-2.61497-0.28000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.2415 - categorical_accuracy: 0.9291 - val_loss: 2.6150 - val_categorical_accuracy: 0.2800 - lr: 8.0000e-06
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2175 - categorical_accuracy: 0.9404
# Epoch 11: saving model to model_init_2022-05-1710_41_14.219633/model-00011-0.21750-0.94042-2.61271-0.30000.h5
# 34/34 [==============================] - 166s 5s/step - loss: 0.2175 - categorical_accuracy: 0.9404 - val_loss: 2.6127 - val_categorical_accuracy: 0.3000 - lr: 8.0000e-06
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2135 - categorical_accuracy: 0.9465
# Epoch 12: saving model to model_init_2022-05-1710_41_14.219633/model-00012-0.21354-0.94646-2.29679-0.37000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.2135 - categorical_accuracy: 0.9465 - val_loss: 2.2968 - val_categorical_accuracy: 0.3700 - lr: 8.0000e-06
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2083 - categorical_accuracy: 0.9502
# Epoch 13: saving model to model_init_2022-05-1710_41_14.219633/model-00013-0.20834-0.95023-1.90706-0.46000.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.5999999959603884e-06.
# 34/34 [==============================] - 165s 5s/step - loss: 0.2083 - categorical_accuracy: 0.9502 - val_loss: 1.9071 - val_categorical_accuracy: 0.4600 - lr: 8.0000e-06
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2110 - categorical_accuracy: 0.9419
# Epoch 14: saving model to model_init_2022-05-1710_41_14.219633/model-00014-0.21095-0.94193-1.53242-0.54000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.2110 - categorical_accuracy: 0.9419 - val_loss: 1.5324 - val_categorical_accuracy: 0.5400 - lr: 1.6000e-06
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2116 - categorical_accuracy: 0.9472
# Epoch 15: saving model to model_init_2022-05-1710_41_14.219633/model-00015-0.21162-0.94721-1.12714-0.61000.h5
# 34/34 [==============================] - 166s 5s/step - loss: 0.2116 - categorical_accuracy: 0.9472 - val_loss: 1.1271 - val_categorical_accuracy: 0.6100 - lr: 1.6000e-06
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2155 - categorical_accuracy: 0.9442
# Epoch 16: saving model to model_init_2022-05-1710_41_14.219633/model-00016-0.21552-0.94419-1.01700-0.63000.h5
# 34/34 [==============================] - 168s 5s/step - loss: 0.2155 - categorical_accuracy: 0.9442 - val_loss: 1.0170 - val_categorical_accuracy: 0.6300 - lr: 1.6000e-06
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2123 - categorical_accuracy: 0.9457
# Epoch 17: saving model to model_init_2022-05-1710_41_14.219633/model-00017-0.21233-0.94570-0.84856-0.67000.h5
# 34/34 [==============================] - 166s 5s/step - loss: 0.2123 - categorical_accuracy: 0.9457 - val_loss: 0.8486 - val_categorical_accuracy: 0.6700 - lr: 1.6000e-06
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2170 - categorical_accuracy: 0.9495
# Epoch 18: saving model to model_init_2022-05-1710_41_14.219633/model-00018-0.21698-0.94947-0.70995-0.76000.h5
# 34/34 [==============================] - 166s 5s/step - loss: 0.2170 - categorical_accuracy: 0.9495 - val_loss: 0.7099 - val_categorical_accuracy: 0.7600 - lr: 1.6000e-06
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1886 - categorical_accuracy: 0.9600
# Epoch 19: saving model to model_init_2022-05-1710_41_14.219633/model-00019-0.18858-0.96003-0.62191-0.75000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.1886 - categorical_accuracy: 0.9600 - val_loss: 0.6219 - val_categorical_accuracy: 0.7500 - lr: 1.6000e-06
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1998 - categorical_accuracy: 0.9480
# Epoch 20: saving model to model_init_2022-05-1710_41_14.219633/model-00020-0.19985-0.94796-0.62224-0.77000.h5
# 34/34 [==============================] - 169s 5s/step - loss: 0.1998 - categorical_accuracy: 0.9480 - val_loss: 0.6222 - val_categorical_accuracy: 0.7700 - lr: 1.6000e-06

# %%
plot(history_model11)
